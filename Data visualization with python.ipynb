# %%
import pandas as pd

# %%
from matplotlib import pyplot as plt

# %%
import numpy as np

# %%
data = pd.read_csv("data.csv", header = 0, index_col = 0)
data
# Out:
#             Temperature  Fuel_Price  MarkDown1  MarkDown2  MarkDown3  \
# Date
# 5/2/2010          42.31       2.572        NaN        NaN        NaN
# 12/2/2010         38.51       2.548        NaN        NaN        NaN
# 19/02/2010        39.93       2.514        NaN        NaN        NaN
# 26/02/2010        46.63       2.561        NaN        NaN        NaN
# 5/3/2010          46.50       2.625        NaN        NaN        NaN
# ...                 ...         ...        ...        ...        ...
# 28/09/2012        76.08       3.666    3666.27       7.64       1.65
# 5/10/2012         68.55       3.617    8077.89        NaN      18.22
# 12/10/2012        62.99       3.601    2086.18        NaN       8.11
# 19/10/2012        67.97       3.594     950.33        NaN       4.93
# 26/10/2012        69.16       3.506    2585.85      31.75       6.00
#
#             MarkDown4  MarkDown5         CPI  Unemployment     Day type  \
# Date
# ...

# %%
random_data = pd.DataFrame(np.random.rand(3,5) , columns = ['MarkDown1', 'Markdown2', 'Markdown3', 'Markdown4', 'Markdown5'], index = [2010,2011,2012])
random_data.plot.area()

data.plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
random_data = pd.DataFrame(np.random.rand(3,2) , columns = ['Fuel_Price', 'Temperature',], index = [2010,2011,2012])
random_data.plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
random_data = pd.DataFrame(np.random.rand(3,3) , columns = ['dept_1sales', 'dept_2sales', 'dept_3sales'], index = [2010,2011,2012])
random_data.plot.barh()
# Out:
# <AxesSubplot:>

# %%
random_data = pd.DataFrame(np.random.rand(3,2) , columns = ['CPI', 'Fuel_Price'], index = [2010,2011,2012])
random_data.plot()
# Out:
# <AxesSubplot:>

# %%
random_data = pd.DataFrame(np.random.rand(3,5) , columns = ['MarkDown1', 'Markdown2', 'Markdown3', 'Markdown4', 'Markdown5'], index = [2010,2011,2012])
new_data = random_data.T

random_data.plot.scatter(x = 'MarkDown1' , y = 'Markdown2')

random_data.plot.scatter(x = 'Markdown3', y = 'Markdown5')
# Out:
# <AxesSubplot:xlabel='Markdown3', ylabel='Markdown5'>

# %%
random_data = pd.DataFrame(np.random.rand(3,2) , columns = ['Unemployment', 'CPI'], index = [2010,2011,2012])
random_data.plot.bar()
# Out:
# <AxesSubplot:>

# %%
data.plot()
# Out:
# <AxesSubplot:xlabel='Date'>
